# %% [markdown]
# # Librerías necesarias
# pyplot nos ayudará con las pruebas recogidas en matrices a exponerlas en gráficos. En cambio, SequentialDecisionTreeAlgorithm es el archivo que contiene la clase SequentialDecisionTreeAlgorithm como propuesta de algoritmo secuencial del alumno.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Para modelo de aprendizaje por árboles de decisión
from lib.SequentialDecisionTreeAlgorithm import SequentialDecisionTreeAlgorithm
# Generalizado para más modelos: árboles de decisión o knn
from lib.SequentialModelAlgorithm import SequentialModelAlgorithm

# Selección de columnas
dataset = pd.read_csv('./datasets/adultDataset.csv', header = 0)
attr_cols = dataset.loc[:, 'capital-gain':'native-country']
obj_col = dataset['income']

# %% [markdown]
# ## Sin ensamble de modelos secuenciales

# %%
from sklearn import tree, preprocessing, model_selection
from sklearn.metrics import balanced_accuracy_score
from sklearn.compose import ColumnTransformer
import sklearn.utils as skl

def attributes_preprocess(attributes_cols):
    # Acumulamos las transformaciones necesarias en una matriz para realizarlas en la función ColumnTransformer
    transforms = []
    for i in attributes_cols: # Recorremos cada columna
        # Primer valor de cada columna. Podríamos recorrer cada valor de la columna para asegurarnos de que sean
        # numéricos o cadena de texto, pero en los Dataset de ejemplo nos vale con comprobar el primer valor.
        fval = attributes_cols[i][0]

        # Comprobamos que sea numérico, sino acumulamos una transformación sobre la columna
        if isinstance(fval, (int, float, np.int64))==False:
            transforms.append(("encode-"+i, preprocessing.OrdinalEncoder(), [i]))

    # Devolvemos como respuesta un array de enteros aplicando las transformaciones acumuladas en transforms
    # # remainder = 'passthrough' nos devolverá en la transformación también las columnas no afectadas
    res = np.array(ColumnTransformer(transforms, remainder='passthrough').fit_transform(attributes_cols), dtype=float)

    return res

# Preprocesado de la columna objetivo. Codifica datos en formato de texto en numéricos  
# @ objetive_col columnas objetivo
def objetive_preproccess(objetive_col):
    # Primer valor de cada columna. Podríamos recorrer cada valor de la columna para asegurarnos de que sean
    # numéricos o cadena de texto, pero en los Dataset de ejemplo nos vale con comprobar el primer valor.
    fval = objetive_col[0]

    if isinstance(fval, (int, float, np.int64))==False:
        objetive_col = preprocessing.LabelEncoder().fit_transform(objetive_col)

    return objetive_col

def classify_prediction(pred):
    Xmax = np.max(pred)
    Xmin = np.min(pred)
    for i in range(len(pred)):
        pred[i] = np.around((pred[i] - Xmin)/(Xmax-Xmin))
    return pred


    attr = attributes_preprocess(attr_cols)
    obj = objetive_preproccess(obj_col)

    (X_train, X_test, y_train, y_test) = model_selection.train_test_split(
            attr, obj,
            random_state=12345,
            test_size=0.33,
            stratify=obj)

    Tree = tree.DecisionTreeRegressor(max_depth=10)
    Tree = Tree.fit(X_train, y_train)
    #Tree.plot_tree(clf)

    cols_mean = attr.mean(axis=0)

    predict = Tree.predict([cols_mean])

print(Tree.score(X_test, y_test))
# Out:
#   File "<ipython-input-32-778c94ed2d89>", line 44
#     attr = attributes_preprocess(attr_cols)
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ## 1. Pruebas en el Dataset adultsDataset
# La primera prueba la realizamos con parámetros predeterminados que usaremos también en las demás pruebas. Esto nos ayudará a fijar unas proporciones y poder comparar los resultados del algoritmo entre diferentes datasets

# %%
print('---- adultDataset.csv ----')
print('Hiperparámetros predeterminados: \n- ntree = 300\n- sample_size = 0.65\n- max_depth = 10\n- lr = 0.1')
SeqTree = SequentialDecisionTreeAlgorithm()
trees, score = SeqTree.start(attributes_cols = attr_cols, objetive_col = obj_col)
print('Score: '+str(score))
# Out:
# ---- adultDataset.csv ----
# Hiperparámetros predeterminados:
# - ntree = 300
# - sample_size = 0.65
# - max_depth = 10
# - lr = 0.1
# Score: 0.9005186117456888

# %% [markdown]
# ### 1.1 Alteración del hiperparámetro ntree
# Con esto aumentaremos o disminuiremos la cantidad de árboles secuenciales en diferentes pruebas. Probaremos fijando los parámetros predeterminados y moviendo solo el parámetro ntrees entre 1 y 500.

# %%
values = [1, 50, 100, 150, 250, 350, 500]
print('\n--- Alterando sample_size ['+str(np.min(values))+' - '+str(np.max(values))+'] ---')
scores = []

for v in range(len(values)):
    SeqTree = SequentialDecisionTreeAlgorithm(ntree = values[v], sample_size = 0.65, max_depth = 10, lr = 0.1)
    trees, score = SeqTree.start(attributes_cols = attr_cols, objetive_col = obj_col)
    scores.append(score)
    
# Realizamos una gráfica para determinar cómo afecta ntree a la puntuación
plt.plot(values, scores)
plt.xlabel('- nTrees -')
plt.ylabel('- Balanced Accuracy Score -')
plt.title('Alteración del hiperparámetro ntrees y manteniendo el resto constante')
plt.show()

m = np.argmax(scores)
print('Mejor puntuación: '+str(scores[m])+' con valor = '+str(values[m]))

print('--------------------------')
print('\n')
# Out:
# --- Alterando sample_size [1 - 500] ---
# Mejor puntuación: 0.9118628588468929 con valor = 350
# --------------------------

# %% [markdown]
# Observamos que a medida que nos acercamos a los 350 árboles obtenemos el máximo valor de puntuación. Es una función logarítmica por lo que no esperamos encontrar mejores valores por más que aumentemos los árboles. Podemos concretar que lo más óptimo sería fijar el algoritmo en 350 árboles al menos para este ejemplo, ya que nos devolvería un resultado similar pero en menor ejecución

# %% [markdown]
# ### 1.2 Alteración del hiperparámetro sample_size

# %%
values = [0.1, 0.25, 0.5, 0.75, 0.9]
print('\n--- Alterando sample_size ['+str(np.min(values))+' - '+str(np.max(values))+'] ---')

scores = []
for v in range(len(values)):
    SeqTree = SequentialDecisionTreeAlgorithm(ntree = 300, sample_size = values[v], max_depth = 10, lr = 0.1)
    trees, score = SeqTree.start(attributes_cols = attr_cols, objetive_col = obj_col)
    scores.append(score)
    
# Realizamos una gráfica para determinar cómo afecta ntree a la puntuación
plt.plot(values, scores)
plt.xlabel('- Proporción sample_size -')
plt.ylabel('- Balanced Accuracy Score -')
plt.title('Alteración del hiperparámetro sample_size')
plt.show()

m = np.argmax(scores)
print('Mejor puntuación: '+str(scores[m])+' con valor = '+str(values[m]))
# Out:
# --- Alterando sample_size [0.1 - 0.9] ---
# Mejor puntuación: 0.9020215788410728 con valor = 0.9

# %% [markdown]
# Debido a la aletoriedad de la muestra, este parámetro no muestra un cambio directo. Comprobamos también realizando el proceso 5 veces y realizando la media de los resultados obtenidos para cada valor (puede tardar bastante):

# %%
values = [0.1, 0.25, 0.5, 0.75, 0.9]
print('\n--- Alterando 5 veces sample_size ['+str(np.min(values))+' - '+str(np.max(values))+'] ---')

tests = []
for j in range(5):
    for v in range(len(values)):
        SeqTree = SequentialDecisionTreeAlgorithm(ntree = 300, sample_size = values[v], max_depth = 10, lr = 0.1)
        trees, score = SeqTree.start(attributes_cols = attr_cols, objetive_col = obj_col)
        if len(tests)<= v:
            tests.append([])
        tests[v].append(score)

print(np.mean(tests, axis=0))
# Realizamos una gráfica para determinar cómo afecta ntree a la puntuación
plt.plot(values, np.mean(tests, axis=0))
plt.xlabel('- Proporción sample_size -')
plt.ylabel('- Balanced Accuracy Score -')
plt.title('Alteración del hiperparámetro sample_size')
plt.show()

m = np.argmax(np.mean(tests, axis=0))
print('Mejor puntuación: '+str(np.mean(tests, axis=0)[m])+' con valor = '+str(values[m]))
# Out:
# --- Alterando 5 veces sample_size [0.1 - 0.9] ---
# [0.89862987 0.89665521 0.9020798  0.89282503 0.89349684]
# Mejor puntuación: 0.9020797991597934 con valor = 0.5

# %% [markdown]
# Podemos decir que cuanta mayor proporción de ejemplos del conjunto de evaluación mayor puntuación obtiene el algoritmo.

# %% [markdown]
# ## 1.3 Alteración del hiperparámetro max_depth

# %%
values = [1, 5, 10, 15, 20]
print('\n--- Alterando max_depth ['+str(np.min(values))+' - '+str(np.max(values))+'] ---')

scores = []
for v in range(len(values)):
    SeqTree = SequentialDecisionTreeAlgorithm(ntree = 300, sample_size = 0.65, max_depth = values[v], lr = 0.1)
    trees, score = SeqTree.start(attributes_cols = attr_cols, objetive_col = obj_col)
    scores.append(score)
    
# Realizamos una gráfica para determinar cómo afecta ntree a la puntuación
plt.plot(values, scores)
plt.xlabel('- max_depth -')
plt.ylabel('- Balanced Accuracy Score -')
plt.title('Alteración del hiperparámetro max_depth')
plt.show()

m = np.argmax(scores)
print('Mejor puntuación: '+str(scores[m])+' con valor = '+str(values[m]))
# Out:
# --- Alterando max_depth [1 - 20] ---
# Mejor puntuación: 0.9119241483786409 con valor = 10

# %% [markdown]
# ### 1.4 Alteración del hiperparámetro de aprendizaje lr

# %%
values = [0.1, 0.25, 0.5, 0.75, 0.9]
print('\n--- Alterando lr ['+str(np.min(values))+' - '+str(np.max(values))+'] ---')

scores = []
for v in range(len(values)):
    SeqTree = SequentialDecisionTreeAlgorithm(ntree = 300, sample_size = 0.65, max_depth = 10, lr = values[v])
    trees, score = SeqTree.start(attributes_cols = attr_cols, objetive_col = obj_col)
    scores.append(score)
    
# Realizamos una gráfica para determinar cómo afecta ntree a la puntuación
plt.plot(values, scores)
plt.xlabel('- lr -')
plt.ylabel('- Balanced Accuracy Score -')
plt.title('Alteración del hiperparámetro de aprendizaje lr')
plt.show()

m = np.argmax(scores)
print('Mejor puntuación: '+str(scores[m])+' con valor = '+str(values[m]))
# Out:
# --- Alterando lr [0.1 - 0.9] ---
# Mejor puntuación: 0.9210153184043275 con valor = 0.25

# %%
values = [0.1, 0.25, 0.5, 0.75, 0.9]
print('\n--- Alterando 5 veces lr ['+str(np.min(values))+' - '+str(np.max(values))+'] ---')

tests = []
for j in range(5):
    for v in range(len(values)):
        SeqTree = SequentialDecisionTreeAlgorithm(ntree = 300, sample_size = 0.65, max_depth = 10, lr = values[v])
        trees, score = SeqTree.start(attributes_cols = attr_cols, objetive_col = obj_col)
        if len(tests)<= v:
            tests.append([])
        tests[v].append(score)

print(np.mean(tests, axis=0))
# Realizamos una gráfica para determinar cómo afecta ntree a la puntuación
plt.plot(values, np.mean(tests, axis=0))
plt.xlabel('- Proporción lr -')
plt.ylabel('- Balanced Accuracy Score -')
plt.title('Alteración del hiperparámetro lr')
plt.show()

m = np.argmax(np.mean(tests, axis=0))
print('Mejor puntuación: '+str(np.mean(tests, axis=0)[m])+' con valor = '+str(values[m]))
# Out:
# --- Alterando 5 veces lr [0.1 - 0.9] ---
# [0.90935954 0.90461854 0.89973575 0.90668713 0.90593361]
# Mejor puntuación: 0.9093595367079773 con valor = 0.1

# %% [markdown]
# ## Exploración y evaluación de otros hiperparámetros
# Evaluaremos hiperparámetros opcionales como min_weight_fraction_leaf, min_samples_leaf y max_features

# %%
values = [0.1, 0.2, 0.3, 0.4]
print('\n--- Alterando min_weight_fraction_leaf ['+str(np.min(values))+' - '+str(np.max(values))+'] ---')

scores = []
for v in range(len(values)):
    SeqTree = SequentialDecisionTreeAlgorithm(ntree = 300, sample_size = 0.65, max_depth = 10, lr = 0.1, min_weight_fraction_leaf=values[v])
    trees, score = SeqTree.start(attributes_cols = attr_cols, objetive_col = obj_col)
    scores.append(score)
    
# Realizamos una gráfica para determinar cómo afecta ntree a la puntuación
plt.plot(values, scores)
plt.xlabel('- lr -')
plt.ylabel('- Balanced Accuracy Score -')
plt.title('Alteración del hiperparámetro de aprendizaje min_weight_fraction_leaf')
plt.show()

m = np.argmax(scores)
print('Mejor puntuación: '+str(scores[m])+' con valor = '+str(values[m]))
# Out:
# --- Alterando min_weight_fraction_leaf [0.1 - 0.4] ---
# Mejor puntuación: 0.7644799597440504 con valor = 0.2

# %%
values = ["auto", "log2", "sqrt"]
print('\n--- Alterando max_features ---')

scores = []
for v in range(len(values)):
    SeqTree = SequentialDecisionTreeAlgorithm(ntree = 300, sample_size = 0.65, max_depth = 10, lr = 0.1, max_features=values[v])
    trees, score = SeqTree.start(attributes_cols = attr_cols, objetive_col = obj_col)
    scores.append(score)
    
# Realizamos una gráfica para determinar cómo afecta ntree a la puntuación
plt.plot(values, scores)
plt.xlabel('- lr -')
plt.ylabel('- Balanced Accuracy Score -')
plt.title('Alteración del hiperparámetro de aprendizaje max_features')
plt.show()

m = np.argmax(scores)
print('Mejor puntuación: '+str(scores[m])+' con valor = '+str(values[m]))
# Out:
# --- Alterando max_features ---
# Mejor puntuación: 0.9011208974378893 con valor = log2

# %%
values = [1, 5, 10, 20]
print('\n--- Alterando min_samples_leaf ['+str(np.min(values))+' - '+str(np.max(values))+'] ---')

scores = []
for v in range(len(values)):
    SeqTree = SequentialDecisionTreeAlgorithm(ntree = 300, sample_size = 0.65, max_depth = 10, lr = 0.1, min_samples_leaf=values[v])
    trees, score = SeqTree.start(attributes_cols = attr_cols, objetive_col = obj_col)
    scores.append(score)
    
# Realizamos una gráfica para determinar cómo afecta ntree a la puntuación
plt.plot(values, scores)
plt.xlabel('- lr -')
plt.ylabel('- Balanced Accuracy Score -')
plt.title('Alteración del hiperparámetro de aprendizaje min_samples_leaf')
plt.show()

m = np.argmax(scores)
print('Mejor puntuación: '+str(scores[m])+' con valor = '+str(values[m]))
# Out:
# --- Alterando min_samples_leaf [1 - 20] ---
# Mejor puntuación: 0.9009756308274788 con valor = 1

# %% [markdown]
# ## 2. Ejemplo con mejor configuración
# Ajustamos con:
# - ntree = 350
# - sample_size = 0.25
# - max_depth = 10
# - lr = 0.25
#
# La alteración de ntree supone una función logarítmica, y después de muchas pruebas para aborrecer la aletoriedad, supone que en 250 ya puede dar el resultado más óptimo con la menor cantidad de árboles que suponen más ejecución.
#
# sample_size no nos ha ofrecido mejores valores

# %%
SeqTree = SequentialDecisionTreeAlgorithm(ntree = 350, sample_size = 0.25, max_depth = 10, lr = 0.25)
trees, score = SeqTree.start(attributes_cols = attr_cols, objetive_col = obj_col)

print('Score final: '+str(score))
# Out:
# Score final: 0.9105984662270998

# %% [markdown]
# ## 3. Ejemplo con knn
# ### Alterando nmodels

# %%
values = [1, 5, 10, 15, 20, 25]
print('\n--- Alterando nmodels ['+str(np.min(values))+' - '+str(np.max(values))+'] ---')
scores = []

for v in range(len(values)):
    SeqModel = SequentialModelAlgorithm(nmodels = values[v], method = "knn")
    models, score = SeqModel.start(attributes_cols = attr_cols, objetive_col = obj_col)
    scores.append(score)
    
# Realizamos una gráfica para determinar cómo afecta ntree a la puntuación
plt.plot(values, scores)
plt.xlabel('- nmodels -')
plt.ylabel('- Balanced Accuracy Score -')
plt.title('Alteración del hiperparámetro nmodels')
plt.show()
m = np.argmax(scores)
print('Mejor puntuación: '+str(scores[m])+' con valor = '+str(values[m]))
# Out:
# --- Alterando nmodels [1 - 25] ---
# Mejor puntuación: 0.8560309846527981 con valor = 20

# %% [markdown]
# ### Alterando n_neighbors

# %%
values = [1, 2, 3, 4, 5]
print('\n--- Alterando n_neighbors ['+str(np.min(values))+' - '+str(np.max(values))+'] ---')
scores = []

for v in range(len(values)):
    SeqModel = SequentialModelAlgorithm(neighbors = values[v], nmodels=10,  method = "knn")
    models, score = SeqModel.start(attributes_cols = attr_cols, objetive_col = obj_col)
    scores.append(score)
    
# Realizamos una gráfica para determinar cómo afecta ntree a la puntuación
plt.plot(values, scores)
plt.xlabel('- nmodels -')
plt.ylabel('- Balanced Accuracy Score -')
plt.title('Alteración del hiperparámetro nmodels')
plt.show()
m = np.argmax(scores)
print('Mejor puntuación: '+str(scores[m])+' con valor = '+str(values[m]))
# Out:
# --- Alterando n_neighbors [1 - 5] ---
# Mejor puntuación: 0.8935434935904601 con valor = 1

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Generalizado para más modelos: árboles de decisión o knn
from lib.SequentialModelAlgorithm import SequentialModelAlgorithm

# Selección de columnas
dataset = pd.read_csv('./datasets/adultDataset.csv', header = 0)
attr_cols = dataset.loc[:, 'capital-gain':'native-country']
obj_col = dataset['income']

# %%
values = [1, 50, 150, 300, 600]
print('\n--- Alterando nmodels ['+str(np.min(values))+' - '+str(np.max(values))+'] ---')
scores = []

for v in range(len(values)):
    SeqTree = SequentialModelAlgorithm(nmodels = values[v], sample_size = 0.65, max_depth = 10, lr = 0.1, random = True)
    trees, score = SeqTree.start(attributes_cols = attr_cols, objetive_col = obj_col)
    scores.append(score)
    
# Realizamos una gráfica para determinar cómo afecta ntree a la puntuación
plt.plot(values, scores)
plt.xlabel('- nTrees -')
plt.ylabel('- Balanced Accuracy Score -')
plt.title('Alteración del hiperparámetro ntrees y manteniendo el resto constante')
plt.show()

m = np.argmax(scores)
print('Mejor puntuación: '+str(scores[m])+' con valor = '+str(values[m]))

print('--------------------------')
print('\n')
# Out:
# --- Alterando nmodels [1 - 600] ---
# Mejor puntuación: 0.9291888032077444 con valor = 300
# --------------------------

# %%
print(trees)
# Out:
# [KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), DecisionTreeRegressor(max_depth=10), DecisionTreeRegressor(max_depth=10), DecisionTreeRegressor(max_depth=10), DecisionTreeRegressor(max_depth=10), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), DecisionTreeRegressor(max_depth=10), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), DecisionTreeRegressor(max_depth=10), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), DecisionTreeRegressor(max_depth=10), DecisionTreeRegressor(max_depth=10), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), DecisionTreeRegressor(max_depth=10), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), DecisionTreeRegressor(max_depth=10), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), DecisionTreeRegressor(max_depth=10), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), DecisionTreeRegressor(max_depth=10), DecisionTreeRegressor(max_depth=10), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), DecisionTreeRegressor(max_depth=10), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), DecisionTreeRegressor(max_depth=10), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), DecisionTreeRegressor(max_depth=10), DecisionTreeRegressor(max_depth=10), DecisionTreeRegressor(max_depth=10), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), DecisionTreeRegressor(max_depth=10), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), DecisionTreeRegressor(max_depth=10), DecisionTreeRegressor(max_depth=10), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), KNeighborsRegressor(n_neighbors=2), DecisionTreeRegressor(max_depth=10), DecisionTreeRegressor(max_depth=10), DecisionTreeRegressor(max_depth=10), DecisionTreeRegressor(max_depth=10), DecisionTreeRegressor(max_depth=10), DecisionTreeRegressor(m ...

# %%
values = [1, 50, 150, 300]
print('\n--- Alterando nmodels ['+str(np.min(values))+' - '+str(np.max(values))+'] ---')
scores = []

for v in range(len(values)):
    SeqTree = SequentialModelAlgorithm(nmodels = values[v], sample_size = 0.65, method="gradient", random = False)
    trees, score = SeqTree.start(attributes_cols = attr_cols, objetive_col = obj_col)
    scores.append(score)
    
# Realizamos una gráfica para determinar cómo afecta ntree a la puntuación
plt.plot(values, scores)
plt.xlabel('- nTrees -')
plt.ylabel('- Balanced Accuracy Score -')
plt.title('Alteración del hiperparámetro ntrees y manteniendo el resto constante')
plt.show()

m = np.argmax(scores)
print('Mejor puntuación: '+str(scores[m])+' con valor = '+str(values[m]))

print('--------------------------')
print('\n')
# Out:
# --- Alterando nmodels [1 - 300] ---
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-de4d97685cad> in <module>
#       5 for v in range(len(values)):
#       6     SeqTree = SequentialModelAlgorithm(nmodels = values[v], sample_size = 0.65, method="gradient", random = False)
# ----> 7     trees, score = SeqTree.start(attributes_cols = attr_cols, objetive_col = obj_col)
#       8     scores.append(score)
#       9
#
# ~\Desktop\ia\entrega\Jupyter\lib\SequentialModelAlgorithm.py in start(self, attributes_cols, objetive_col, random_state, ftest_size)
#      71         models = []
#      72         for i in range(self.nmodels):
# ---> 73             submodel, self.pred = self.meta_algorithm(X_test, y_test, self.pred)
#      74             models.append(submodel)
#      75
#
# ~\Desktop\ia\entrega\Jupyter\lib\SequentialModelAlgorithm.py in meta_algorithm(self, X, y, prediction)
#     127             submodel = random.choice([tree.DecisionTreeRegressor(max_depth=self.max_depth, min_samples_leaf=self.min_samples_leaf, max_features=self.max_features, min_weight_fraction_leaf=self.min_weight_fraction_leaf), KNeighborsRegressor(n_neighbors=self.neighbors)])
#     128
# --> 129         submodel = submodel.fit(Xm, i_resm)
#     130         i_prediction = prediction + submodel.predict(X)*self.lr
#     131
#
# D:\windows10_folders\Archivos_De_Programas\Anaconda3\lib\site-packages\sklearn\pipeline.py in fit(self, X, y, **fit_params)
#     344             if self._final_estimator != 'passthrough':
#     345                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 346                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     347
#     348         return self
#
# D:\windows10_folders\Archivos_De_Programas\Anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py in fit(self, X, y, coef_init, intercept_init, sample_weight)
#     727             Returns an instance of self.
#     728         """
# --> 729         return self._fit(X, y, alpha=self.alpha, C=1.0,
#     730                          loss=self.loss, learning_rate=self.learning_rate,
#     731                          coef_init=coef_init, intercept_init=intercept_init,
#
# D:\windows10_folders\Archivos_De_Programas\Anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py in _fit(self, X, y, alpha, C, loss, learning_rate, coef_init, intercept_init, sample_weight)
#     567         self.t_ = 1.0
#     568
# --> 569         self._partial_fit(X, y, alpha, C, loss, learning_rate, self.max_iter,
#     570                           classes, sample_weight, coef_init, intercept_init)
#     571
#
# D:\windows10_folders\Archivos_De_Programas\Anaconda3\lib\site-packages\sklearn\linear_model\_stochastic_gradient.py in _partial_fit(self, X, y, alpha, C, loss, learning_rate, max_iter, classes, sample_weight, coef_init, intercept_init)
#     497         n_samples, n_features = X.shape
#     498
# --> 499         _check_partial_fit_first_call(self, classes)
#     500
#     501         n_classes = self.classes_.shape[0]
#
# D:\windows10_folders\Archivos_De_Programas\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in _check_partial_fit_first_call(clf, classes)
#     337         else:
#     338             # This is the first call to partial_fit
# --> 339             clf.classes_ = unique_labels(classes)
#     340             return True
#     341
#
# D:\windows10_folders\Archivos_De_Programas\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in unique_labels(*ys)
#      96     _unique_labels = _FN_UNIQUE_LABELS.get(label_type, None)
#      97     if not _unique_labels:
# ---> 98         raise ValueError("Unknown label type: %s" % repr(ys))
#      99
#     100     ys_labels = set(chain.from_iterable(_unique_labels(y) for y in ys))
#
# ValueError: Unknown label type: (array([-0.1,  0. ,  0.9,  1. ]),)
